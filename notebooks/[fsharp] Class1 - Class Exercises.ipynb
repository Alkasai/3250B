// %%
#r "nuget:Deedle.Interactive,3.0.0-beta.1"
#r "nuget:FSharp.Stats"

// https://stackoverflow.com/a/74260934/977406
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Deedle.Interactive, 3.0.0-beta.1</span></li><li><span>FSharp.Stats, 0.4.8</span></li></ul></div></div>

// %%
open Deedle

// %%
let df = Frame.ReadCsv("MessyData.csv")

// %% [markdown]
// ### Wrong data types

// %%
// https://stackoverflow.com/a/74260934/977406

let info (df: Deedle.Frame<'a,'b>) =
    let dt = df.GetFrameData()
    let countOptionalValues d =
        d
        |> Seq.filter (
            function
            | OptionalValue.Present _ -> true
            | _ -> false
        )
        |> Seq.length

    Seq.zip dt.ColumnKeys dt.Columns
    |> Seq.map (fun (col, (ty, vec)) ->
        {|
            Column = col
            ``Non-Null Count`` =
                match vec.Data with
                | Vectors.VectorData.DenseList d -> $"%i{d |> Seq.length} non-null"
                | Vectors.VectorData.SparseList d -> $"%i{d |> countOptionalValues} non-null"
                | Vectors.VectorData.Sequence d -> $"%i{d |> countOptionalValues} non-null"
            Dtype = ty
        |}
    )

// %%
df |> info
// Out:
// <table><thead><tr><th><i>index</i></th><th>Column</th><th>Dtype</th><th>Non-Null Count</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext">[ Name ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>1</td><td><div class="dni-plaintext">[ PhoneNumber ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>2</td><td><div class="dni-plaintext">[ City ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>3</td><td><div class="dni-plaintext">[ Address ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>4</td><td><div class="dni-plaintext">[ PostalCode ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>5</td><td><div class="dni-plaintext">[ BirthDate ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.datetime?view=net-5.0">System.DateTime</a></span></td><td>30 non-null</td></tr><tr><td>6</td><td><div class="dni-plaintext">[ Income ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.int32?view=net-5.0">System.Int32</a></span></td><td>26 non-null</td></tr><tr><td>7</td><td><div class="dni-plaintext">[ CreditLimit ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr><tr><td>8</td><td><div class="dni-plaintext">[ MaritalStatus ]</div></td><td><span><a href="https://docs.microsoft.com/dotnet/api/system.string?view=net-5.0">System.String</a></span></td><td>30 non-null</td></tr></tbody></table>

// %%
df |> Frame.fillMissing Direction.Backward

// %%
df['CreditLimit'] = pd.to_numeric(df['CreditLimit'], errors='coerce')

// %%
df.info()
// Out:
// <class 'pandas.core.frame.DataFrame'>
// RangeIndex: 30 entries, 0 to 29
// Data columns (total 9 columns):
//  #   Column         Non-Null Count  Dtype
// ---  ------         --------------  -----
//  0   Name           30 non-null     object
//  1   PhoneNumber    30 non-null     object
//  2   City           30 non-null     object
//  3   Address        30 non-null     object
//  4   PostalCode     30 non-null     object
//  5   BirthDate      30 non-null     object
//  6   Income         26 non-null     float64
//  7   CreditLimit    29 non-null     float64
//  8   MaritalStatus  24 non-null     object
// dtypes: float64(2), object(7)
// memory usage: 2.2+ KB

// %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])

// %%
df.info()
// Out:
// <class 'pandas.core.frame.DataFrame'>
// RangeIndex: 30 entries, 0 to 29
// Data columns (total 9 columns):
//  #   Column         Non-Null Count  Dtype
// ---  ------         --------------  -----
//  0   Name           30 non-null     object
//  1   PhoneNumber    30 non-null     object
//  2   City           30 non-null     object
//  3   Address        30 non-null     object
//  4   PostalCode     30 non-null     object
//  5   BirthDate      30 non-null     datetime64[ns]
//  6   Income         26 non-null     float64
//  7   CreditLimit    29 non-null     float64
//  8   MaritalStatus  24 non-null     object
// dtypes: datetime64[ns](1), float64(2), object(6)
// memory usage: 2.2+ KB

// %%
for i in df['BirthDate']:
    print(i.year)
// Out:
// 1987
// 1991
// 2052
// 1981
// 2001
// 2001
// 1976
// 2062
// 1976
// 2003
// 2068
// 1998
// 1974
// 1977
// 1987
// 1978
// 2062
// 1984
// 2056
// 1995
// 2058
// 1983
// 1991
// 2001
// 2065
// 1984
// 1989
// 2058
// 1990
// 1991

// %%
def fix_year(i):
    if i.year > datetime.date.today().year:
        year = i.year - 100
    else:
        year = i.year
    return datetime.datetime(year, i.month, i.day)

// %%
df['BirthDate'] = df['BirthDate'].apply(fix_year)

// %%
df.info()
// Out:
// <class 'pandas.core.frame.DataFrame'>
// RangeIndex: 30 entries, 0 to 29
// Data columns (total 9 columns):
//  #   Column         Non-Null Count  Dtype
// ---  ------         --------------  -----
//  0   Name           30 non-null     object
//  1   PhoneNumber    30 non-null     object
//  2   City           30 non-null     object
//  3   Address        30 non-null     object
//  4   PostalCode     30 non-null     object
//  5   BirthDate      30 non-null     datetime64[ns]
//  6   Income         30 non-null     float64
//  7   CreditLimit    30 non-null     float64
//  8   MaritalStatus  30 non-null     object
// dtypes: datetime64[ns](1), float64(2), object(6)
// memory usage: 2.2+ KB

// %%
df['PhoneNumber'].unique()
// Out:
// array(['8675550155', '867-555-0148', '613-555-0111', '204-555-0105',
//        '902555-0157', '902-555-0177', '204-555-0136', '416-555-0159',
//        '204-555-0189', '902-555-0108', '416-5550167', '902-555-0195',
//        '204-555-0195', '204-555-0180', '613-555-0154', '613-555-0150',
//        '416-5550180', '867-555-0113', '416-555-0192', '902-555-0190',
//        '4165550170', '204-555-0190', '902-555-0138', '613-555-0116',
//        '613-555-0165', '867-555-0158', '867-555-0161', '416-555-0198',
//        '867-555-0134', '613-555-0139'], dtype=object)

// %%
phonePattern1 = re.compile(r'^(\d{3})-(\d{3})-(\d{4})$')  #(r'\d\d\d-\d\d\d-\d\d\d\d')
phonePattern2 = re.compile(r'^(\d{10})$')
phonePattern3 = re.compile(r'^(\d{6})-(\d{4})$')
phonePattern4 = re.compile(r'^(\d{3})-(\d{7})$')


def phonePatternFix(x):
    if phonePattern1.search(x) != None:
        return x
    elif phonePattern2.search(x) != None:
        return '-'.join([x[:3],x[3:6],x[6:]])
    elif phonePattern3.search(x) != None:
        return '-'.join([x[:3],x[3:]])
    elif phonePattern4.search(x) != None:
        return '-'.join([x[:7],x[7:]])
    else:
        return "pattern not found"

// %%
phonePattern1.search('613-555-0150').group(1)
// Out:
// '613'

// %%
df['PhoneNumber'] = df['PhoneNumber'].apply(phonePatternFix)

// %%
df['PhoneNumber'].unique()
// Out:
// array(['867-555-0155', '867-555-0148', '613-555-0111', '204-555-0105',
//        '902-555-0157', '902-555-0177', '204-555-0136', '416-555-0159',
//        '204-555-0189', '902-555-0108', '416-555-0167', '902-555-0195',
//        '204-555-0195', '204-555-0180', '613-555-0154', '613-555-0150',
//        '416-555-0180', '867-555-0113', '416-555-0192', '902-555-0190',
//        '416-555-0170', '204-555-0190', '902-555-0138', '613-555-0116',
//        '613-555-0165', '867-555-0158', '867-555-0161', '416-555-0198',
//        '867-555-0134', '613-555-0139'], dtype=object)

// %% [markdown]
// ### Data mistakes

// %%
df.City.unique()
// Out:
// array(['Yellowknife', 'Ottawa', 'Winnipeg', 'Charlottetown',
//        'Charlotttetownn', 'Toronto', 'Winnipegg', 'Ottawas', 'Toronot'],
//       dtype=object)

// %%
df['City'] = df['City'].replace(r"^Winnipegg$","Winnipeg", regex=True)
df['City'] = df['City'].replace(r"^Charlotttetownn$","Charlottetown", regex=True)
df['City'] = df['City'].replace(r"^Ottawas$","Ottawa", regex=True)
df['City'] = df['City'].replace(r"^Toronot$","Toronto", regex=True)

// %%
df.City.unique()
// Out:
// array(['Yellowknife', 'Ottawa', 'Winnipeg', 'Charlottetown', 'Toronto'],
//       dtype=object)

// %% [markdown]
// ### Missing data

// %%
df.dropna().describe(include='all')
// Out:
//                         Name   PhoneNumber         City  \
// count                     21            21           21
// unique                    21            21            5
// top     Thane Arthur Andrews  867-555-0155  Yellowknife
// freq                       1             1            6
// mean                     NaN           NaN          NaN
// std                      NaN           NaN          NaN
// min                      NaN           NaN          NaN
// 25%                      NaN           NaN          NaN
// 50%                      NaN           NaN          NaN
// 75%                      NaN           NaN          NaN
// max                      NaN           NaN          NaN
//
//                         Address PostalCode   BirthDate         Income  \
// count                        21         21          21      21.000000
// unique                       21         19          21            NaN
// top     25 West Arlington Drive     R3R3B6  1987-01-30            NaN
// freq                          1          2           1            NaN
// mean                        NaN        NaN         NaN  106222.238095
// std                         NaN        NaN         NaN   56543.729211
// min                         NaN        NaN         NaN   18475.000000
// 25%                         NaN        NaN         NaN   60658.000000
// 50%                         NaN        NaN         NaN  117630.000000
// 75%                         NaN        NaN         NaN  147312.000000
// max                         NaN        NaN         NaN  256360.000000
//
//         CreditLimit MaritalStatus
// count     21.000000            21
// unique          NaN             3
// top             NaN        Single
// freq            NaN             8
// mean    3147.619048           NaN
// std     1415.492511           NaN
// min      500.000000           NaN
// 25%     2500.000000           NaN
// 50%     3500.000000           NaN
// 75%     4000.000000           NaN
// max     5000.000000           NaN

// %%
df.describe(include='all')
// Out:
//                         Name   PhoneNumber         City  \
// count                     30            30           30
// unique                    30            30            5
// top     Thane Arthur Andrews  867-555-0155  Yellowknife
// freq                       1             1            6
// mean                     NaN           NaN          NaN
// std                      NaN           NaN          NaN
// min                      NaN           NaN          NaN
// 25%                      NaN           NaN          NaN
// 50%                      NaN           NaN          NaN
// 75%                      NaN           NaN          NaN
// max                      NaN           NaN          NaN
//
//                         Address PostalCode   BirthDate         Income  \
// count                        30         30          30      26.000000
// unique                       30         27          30            NaN
// top     25 West Arlington Drive     R3R3B6  1987-01-30            NaN
// freq                          1          2           1            NaN
// mean                        NaN        NaN         NaN  104742.461538
// std                         NaN        NaN         NaN   52935.742490
// min                         NaN        NaN         NaN   18475.000000
// 25%                         NaN        NaN         NaN   66131.250000
// 50%                         NaN        NaN         NaN  107770.500000
// 75%                         NaN        NaN         NaN  146980.750000
// max                         NaN        NaN         NaN  256360.000000
//
//         CreditLimit MaritalStatus
// count     29.000000            24
// unique          NaN             3
// top             NaN       Married
// freq            NaN             9
// mean    3055.172414           NaN
// std     1403.970443           NaN
// min      500.000000           NaN
// 25%     2500.000000           NaN
// 50%     3000.000000           NaN
// 75%     4000.000000           NaN
// max     5000.000000           NaN

// %%
df.groupby('MaritalStatus')['Income'].mean()
// Out:
// MaritalStatus
// Divorced     93346.000
// Married      94709.000
// Single      125783.125
// Name: Income, dtype: float64

// %%
df['MaritalStatus'] = df['MaritalStatus'].fillna('Unknown')

// %%
df
// Out:
//                              Name   PhoneNumber           City  \
// 0            Thane Arthur Andrews  867-555-0155    Yellowknife
// 1                   Ty Tiina Hume  867-555-0148    Yellowknife
// 2                   Anita Travert  613-555-0111         Ottawa
// 3       Odilon Vera Ó Maoil Riain  204-555-0105       Winnipeg
// 4                Dot Cloé Jonasen  902-555-0157  Charlottetown
// 5        Aoibhín Chinyere Léandre  902-555-0177  Charlottetown
// 6                    Aksel Parent  204-555-0136       Winnipeg
// 7            Helgi Lessie Castelo  416-555-0159        Toronto
// 8      Heaven Maximilienne Austin  204-555-0189       Winnipeg
// 9        Pippa Stéphane Chevalier  902-555-0108  Charlottetown
// 10   Flurry Annikki Ó Ceallacháin  416-555-0167        Toronto
// 11            Tanzi Liisi Alescio  902-555-0195  Charlottetown
// 12             Sofia Vodenicharov  204-555-0195       Winnipeg
// 13            Eldred Sonia Henson  204-555-0180       Winnipeg
// 14        Donelle Rowland Coghlan  613-555-0154         Ottawa
// 15           Burke Mandla Collins  613-555-0150         Ottawa
// 16                     Aku Ahearn  416-555-0180        Toronto
// 17       Agostino Morgana Hashemi  867-555-0113    Yellowknife
// 18        Ilija Stoyan Descoteaux  416-555-0192        Toronto
// 19              Serafim Proudfoot  902-555-0190  Charlottetown
// 20          Eufêmia Jamshed Baldi  416-555-0170        Toronto
// 21                   Boris Jenson  204-555-0190       Winnipeg
// 22                   Seosamh Gibb  902-555-0138  Charlottetown
// 23                  Storm Hampton  613-555-0116         Ottawa
// 24          Marlyn Mathias Sander  613-555-0165         Ottawa
// 25  Bjarne Brooklynn Christophers  867-555-0158    Yellowknife
// 26                  Jón Zak Falco  867-555-0161    Yellowknife
// 27          Severi Johanne Keegan  416-555-0198        Toronto
// 28           Giampaolo Stefánsson  867-555-0134    Yellowknife
// 29        Valéria Zuri Anthonyson  613-555-0139         Ottawa
//
//                       Address PostalCode   BirthDate    Income  CreditLimit  \
// 0     25 West Arlington Drive     X1A3C7  1987-01-30   77569.0        500.0
// 1          214 West Maple Dr.     X1A3J6  1991-09-05  117630.0       5000.0
// 2         24 Constitution St.     K2B8E3  1952-05-02       NaN       3000.0
// 3       7941 Greenview Street     R3G2J6  1981-10-31   97911.0       4000.0
// 4            74 Monroe Street     C1A2V3  2001-07-25       NaN          NaN
// 5      7282 E. Redwood Street     C1A1T1  2001-03-24  157027.0       4500.0
// 6               27 Queen Road     R2V1H5  1976-05-19   60658.0       5000.0
// 7         438 E. Cypress Ave.     M5V3N2  1962-03-15       NaN        500.0
// 8          7471 Rockcrest St.     R2G3B5  1976-11-05  152732.0       3500.0
// 9          692 Thompson Drive     C1C1N8  2003-06-06  125318.0       3000.0
// 10      8614 Riverside Avenue     M5H0H1  1968-07-25   68145.0       1000.0
// 11        175 E. Dunbar Drive     C1A8H3  1998-07-24  118766.0       4000.0
// 12        883 High Point Lane     R3T1C3  1974-03-08  120311.0       2500.0
// 13      832 Oak Meadow Avenue     R3R3B6  1977-06-27   53013.0       3000.0
// 14               5 Wilson Rd.     K2A3N2  1987-06-01   75545.0       1000.0
// 15             73 Morris Ave.     K1Y0E1  1978-07-06  147312.0       2500.0
// 16                46 Clay St.     M4E3N1  1962-01-24   57954.0       3000.0
// 17        324 Paris Hill Road     X1A1X7  1984-05-31  149273.0       3800.0
// 18      306 North Oxford Lane     M1J1Z7  1956-11-03  256360.0       4000.0
// 19        1 Sleepy Hollow Rd.     A0C1L0  1995-09-01   65460.0       3000.0
// 20  7648 Indian Summer Street     M5E0A5  1958-02-27  155676.0       4500.0
// 21               69 Main Lane     R3R3B6  1983-02-17   45923.0       4500.0
// 22             931 Myers Ave.     C1A3W7  1991-09-09       NaN       3500.0
// 23       7437 Longfellow Lane     K2C1R1  2001-04-03   18475.0        500.0
// 24              35 Wayne Road     K2B8E3  1965-07-31   73759.0       3500.0
// 25        307 Railroad Street     X1A1Z2  1984-08-15   27138.0       3000.0
// 26      95 North San Juan St.     X1A3J6  1989-02-04  127768.0       1000.0
// 27           8798 Church Road     M4N2S1  1958-03-23   75039.0       3800.0
// 28          98 Williams Drive     X1A2Y5  1990-10-24  145987.0       2500.0
// 29    779 E. Birch Hill Court     K2C2R3  1991-07-21  152555.0       5000.0
//
//    MaritalStatus
// 0         Single
// 1       Divorced
// 2        Married
// 3       Divorced
// 4        Unknown
// 5         Single
// 6         Single
// 7       Divorced
// 8         Single
// 9        Unknown
// 10       Married
// 11       Married
// 12       Married
// 13       Married
// 14       Unknown
// 15      Divorced
// 16      Divorced
// 17       Married
// 18        Single
// 19       Unknown
// 20        Single
// 21      Divorced
// 22      Divorced
// 23        Single
// 24       Unknown
// 25       Married
// 26        Single
// 27       Married
// 28       Married
// 29       Unknown

// %%
df['CreditLimit'] = df['CreditLimit'].fillna(df['CreditLimit'].median())

// %%
df
// Out:
//                              Name   PhoneNumber           City  \
// 0            Thane Arthur Andrews  867-555-0155    Yellowknife
// 1                   Ty Tiina Hume  867-555-0148    Yellowknife
// 2                   Anita Travert  613-555-0111         Ottawa
// 3       Odilon Vera Ó Maoil Riain  204-555-0105       Winnipeg
// 4                Dot Cloé Jonasen  902-555-0157  Charlottetown
// 5        Aoibhín Chinyere Léandre  902-555-0177  Charlottetown
// 6                    Aksel Parent  204-555-0136       Winnipeg
// 7            Helgi Lessie Castelo  416-555-0159        Toronto
// 8      Heaven Maximilienne Austin  204-555-0189       Winnipeg
// 9        Pippa Stéphane Chevalier  902-555-0108  Charlottetown
// 10   Flurry Annikki Ó Ceallacháin  416-555-0167        Toronto
// 11            Tanzi Liisi Alescio  902-555-0195  Charlottetown
// 12             Sofia Vodenicharov  204-555-0195       Winnipeg
// 13            Eldred Sonia Henson  204-555-0180       Winnipeg
// 14        Donelle Rowland Coghlan  613-555-0154         Ottawa
// 15           Burke Mandla Collins  613-555-0150         Ottawa
// 16                     Aku Ahearn  416-555-0180        Toronto
// 17       Agostino Morgana Hashemi  867-555-0113    Yellowknife
// 18        Ilija Stoyan Descoteaux  416-555-0192        Toronto
// 19              Serafim Proudfoot  902-555-0190  Charlottetown
// 20          Eufêmia Jamshed Baldi  416-555-0170        Toronto
// 21                   Boris Jenson  204-555-0190       Winnipeg
// 22                   Seosamh Gibb  902-555-0138  Charlottetown
// 23                  Storm Hampton  613-555-0116         Ottawa
// 24          Marlyn Mathias Sander  613-555-0165         Ottawa
// 25  Bjarne Brooklynn Christophers  867-555-0158    Yellowknife
// 26                  Jón Zak Falco  867-555-0161    Yellowknife
// 27          Severi Johanne Keegan  416-555-0198        Toronto
// 28           Giampaolo Stefánsson  867-555-0134    Yellowknife
// 29        Valéria Zuri Anthonyson  613-555-0139         Ottawa
//
//                       Address PostalCode   BirthDate    Income  CreditLimit  \
// 0     25 West Arlington Drive     X1A3C7  1987-01-30   77569.0        500.0
// 1          214 West Maple Dr.     X1A3J6  1991-09-05  117630.0       5000.0
// 2         24 Constitution St.     K2B8E3  1952-05-02       NaN       3000.0
// 3       7941 Greenview Street     R3G2J6  1981-10-31   97911.0       4000.0
// 4            74 Monroe Street     C1A2V3  2001-07-25       NaN       3000.0
// 5      7282 E. Redwood Street     C1A1T1  2001-03-24  157027.0       4500.0
// 6               27 Queen Road     R2V1H5  1976-05-19   60658.0       5000.0
// 7         438 E. Cypress Ave.     M5V3N2  1962-03-15       NaN        500.0
// 8          7471 Rockcrest St.     R2G3B5  1976-11-05  152732.0       3500.0
// 9          692 Thompson Drive     C1C1N8  2003-06-06  125318.0       3000.0
// 10      8614 Riverside Avenue     M5H0H1  1968-07-25   68145.0       1000.0
// 11        175 E. Dunbar Drive     C1A8H3  1998-07-24  118766.0       4000.0
// 12        883 High Point Lane     R3T1C3  1974-03-08  120311.0       2500.0
// 13      832 Oak Meadow Avenue     R3R3B6  1977-06-27   53013.0       3000.0
// 14               5 Wilson Rd.     K2A3N2  1987-06-01   75545.0       1000.0
// 15             73 Morris Ave.     K1Y0E1  1978-07-06  147312.0       2500.0
// 16                46 Clay St.     M4E3N1  1962-01-24   57954.0       3000.0
// 17        324 Paris Hill Road     X1A1X7  1984-05-31  149273.0       3800.0
// 18      306 North Oxford Lane     M1J1Z7  1956-11-03  256360.0       4000.0
// 19        1 Sleepy Hollow Rd.     A0C1L0  1995-09-01   65460.0       3000.0
// 20  7648 Indian Summer Street     M5E0A5  1958-02-27  155676.0       4500.0
// 21               69 Main Lane     R3R3B6  1983-02-17   45923.0       4500.0
// 22             931 Myers Ave.     C1A3W7  1991-09-09       NaN       3500.0
// 23       7437 Longfellow Lane     K2C1R1  2001-04-03   18475.0        500.0
// 24              35 Wayne Road     K2B8E3  1965-07-31   73759.0       3500.0
// 25        307 Railroad Street     X1A1Z2  1984-08-15   27138.0       3000.0
// 26      95 North San Juan St.     X1A3J6  1989-02-04  127768.0       1000.0
// 27           8798 Church Road     M4N2S1  1958-03-23   75039.0       3800.0
// 28          98 Williams Drive     X1A2Y5  1990-10-24  145987.0       2500.0
// 29    779 E. Birch Hill Court     K2C2R3  1991-07-21  152555.0       5000.0
//
//    MaritalStatus
// 0         Single
// 1       Divorced
// 2        Married
// 3       Divorced
// 4        Unknown
// 5         Single
// 6         Single
// 7       Divorced
// 8         Single
// 9        Unknown
// 10       Married
// 11       Married
// 12       Married
// 13       Married
// 14       Unknown
// 15      Divorced
// 16      Divorced
// 17       Married
// 18        Single
// 19       Unknown
// 20        Single
// 21      Divorced
// 22      Divorced
// 23        Single
// 24       Unknown
// 25       Married
// 26        Single
// 27       Married
// 28       Married
// 29       Unknown

// %%
df.groupby('City')['Income'].mean()
// Out:
// City
// Charlottetown    116642.750000
// Ottawa            93529.200000
// Toronto          122634.800000
// Winnipeg          88424.666667
// Yellowknife      107560.833333
// Name: Income, dtype: float64

// %%
df.groupby('City')['Income'].median()
// Out:
// City
// Charlottetown    122042.0
// Ottawa            75545.0
// Toronto           75039.0
// Winnipeg          79284.5
// Yellowknife      122699.0
// Name: Income, dtype: float64

// %%
df['Income'].median()
// Out:
// 107770.5

// %%
df.groupby('City')['Income'].transform('median')
// Out:
// 0     122699.0
// 1     122699.0
// 2      75545.0
// 3      79284.5
// 4     122042.0
// 5     122042.0
// 6      79284.5
// 7      75039.0
// 8      79284.5
// 9     122042.0
// 10     75039.0
// 11    122042.0
// 12     79284.5
// 13     79284.5
// 14     75545.0
// 15     75545.0
// 16     75039.0
// 17    122699.0
// 18     75039.0
// 19    122042.0
// 20     75039.0
// 21     79284.5
// 22    122042.0
// 23     75545.0
// 24     75545.0
// 25    122699.0
// 26    122699.0
// 27     75039.0
// 28    122699.0
// 29     75545.0
// Name: Income, dtype: float64

// %%
df['Income'] = df['Income'].fillna(df.groupby('City')['Income'].transform('median'))

// %%
df
// Out:
//                              Name   PhoneNumber           City  \
// 0            Thane Arthur Andrews  867-555-0155    Yellowknife
// 1                   Ty Tiina Hume  867-555-0148    Yellowknife
// 2                   Anita Travert  613-555-0111         Ottawa
// 3       Odilon Vera Ó Maoil Riain  204-555-0105       Winnipeg
// 4                Dot Cloé Jonasen  902-555-0157  Charlottetown
// 5        Aoibhín Chinyere Léandre  902-555-0177  Charlottetown
// 6                    Aksel Parent  204-555-0136       Winnipeg
// 7            Helgi Lessie Castelo  416-555-0159        Toronto
// 8      Heaven Maximilienne Austin  204-555-0189       Winnipeg
// 9        Pippa Stéphane Chevalier  902-555-0108  Charlottetown
// 10   Flurry Annikki Ó Ceallacháin  416-555-0167        Toronto
// 11            Tanzi Liisi Alescio  902-555-0195  Charlottetown
// 12             Sofia Vodenicharov  204-555-0195       Winnipeg
// 13            Eldred Sonia Henson  204-555-0180       Winnipeg
// 14        Donelle Rowland Coghlan  613-555-0154         Ottawa
// 15           Burke Mandla Collins  613-555-0150         Ottawa
// 16                     Aku Ahearn  416-555-0180        Toronto
// 17       Agostino Morgana Hashemi  867-555-0113    Yellowknife
// 18        Ilija Stoyan Descoteaux  416-555-0192        Toronto
// 19              Serafim Proudfoot  902-555-0190  Charlottetown
// 20          Eufêmia Jamshed Baldi  416-555-0170        Toronto
// 21                   Boris Jenson  204-555-0190       Winnipeg
// 22                   Seosamh Gibb  902-555-0138  Charlottetown
// 23                  Storm Hampton  613-555-0116         Ottawa
// 24          Marlyn Mathias Sander  613-555-0165         Ottawa
// 25  Bjarne Brooklynn Christophers  867-555-0158    Yellowknife
// 26                  Jón Zak Falco  867-555-0161    Yellowknife
// 27          Severi Johanne Keegan  416-555-0198        Toronto
// 28           Giampaolo Stefánsson  867-555-0134    Yellowknife
// 29        Valéria Zuri Anthonyson  613-555-0139         Ottawa
//
//                       Address PostalCode   BirthDate    Income  CreditLimit  \
// 0     25 West Arlington Drive     X1A3C7  1987-01-30   77569.0        500.0
// 1          214 West Maple Dr.     X1A3J6  1991-09-05  117630.0       5000.0
// 2         24 Constitution St.     K2B8E3  1952-05-02   75545.0       3000.0
// 3       7941 Greenview Street     R3G2J6  1981-10-31   97911.0       4000.0
// 4            74 Monroe Street     C1A2V3  2001-07-25  122042.0       3000.0
// 5      7282 E. Redwood Street     C1A1T1  2001-03-24  157027.0       4500.0
// 6               27 Queen Road     R2V1H5  1976-05-19   60658.0       5000.0
// 7         438 E. Cypress Ave.     M5V3N2  1962-03-15   75039.0        500.0
// 8          7471 Rockcrest St.     R2G3B5  1976-11-05  152732.0       3500.0
// 9          692 Thompson Drive     C1C1N8  2003-06-06  125318.0       3000.0
// 10      8614 Riverside Avenue     M5H0H1  1968-07-25   68145.0       1000.0
// 11        175 E. Dunbar Drive     C1A8H3  1998-07-24  118766.0       4000.0
// 12        883 High Point Lane     R3T1C3  1974-03-08  120311.0       2500.0
// 13      832 Oak Meadow Avenue     R3R3B6  1977-06-27   53013.0       3000.0
// 14               5 Wilson Rd.     K2A3N2  1987-06-01   75545.0       1000.0
// 15             73 Morris Ave.     K1Y0E1  1978-07-06  147312.0       2500.0
// 16                46 Clay St.     M4E3N1  1962-01-24   57954.0       3000.0
// 17        324 Paris Hill Road     X1A1X7  1984-05-31  149273.0       3800.0
// 18      306 North Oxford Lane     M1J1Z7  1956-11-03  256360.0       4000.0
// 19        1 Sleepy Hollow Rd.     A0C1L0  1995-09-01   65460.0       3000.0
// 20  7648 Indian Summer Street     M5E0A5  1958-02-27  155676.0       4500.0
// 21               69 Main Lane     R3R3B6  1983-02-17   45923.0       4500.0
// 22             931 Myers Ave.     C1A3W7  1991-09-09  122042.0       3500.0
// 23       7437 Longfellow Lane     K2C1R1  2001-04-03   18475.0        500.0
// 24              35 Wayne Road     K2B8E3  1965-07-31   73759.0       3500.0
// 25        307 Railroad Street     X1A1Z2  1984-08-15   27138.0       3000.0
// 26      95 North San Juan St.     X1A3J6  1989-02-04  127768.0       1000.0
// 27           8798 Church Road     M4N2S1  1958-03-23   75039.0       3800.0
// 28          98 Williams Drive     X1A2Y5  1990-10-24  145987.0       2500.0
// 29    779 E. Birch Hill Court     K2C2R3  1991-07-21  152555.0       5000.0
//
//    MaritalStatus
// 0         Single
// 1       Divorced
// 2        Married
// 3       Divorced
// 4        Unknown
// 5         Single
// 6         Single
// 7       Divorced
// 8         Single
// 9        Unknown
// 10       Married
// 11       Married
// 12       Married
// 13       Married
// 14       Unknown
// 15      Divorced
// 16      Divorced
// 17       Married
// 18        Single
// 19       Unknown
// 20        Single
// 21      Divorced
// 22      Divorced
// 23        Single
// 24       Unknown
// 25       Married
// 26        Single
// 27       Married
// 28       Married
// 29       Unknown
